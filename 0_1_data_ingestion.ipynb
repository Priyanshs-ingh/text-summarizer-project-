# %%
import os

# %%
# %pwd
# Out:
# 'c:\\text-summarizer-project-'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionconfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path
    path_to_yaml: Path

# %%
# %pip install textSummarizer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

# Get the directory of the current script
script_dir = os.path.dirname(os.path.abspath(__file__))

# Build the path to the configuration file
config_path = os.path.join(script_dir, 'config.txt')

# Now, you can open and read the configuration file
with open(config_path, 'r') as file:
    config = file.read()
    print(config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 4
#       1 import os
#       3 # Get the directory of the current script
# ----> 4 script_dir = os.path.dirname(os.path.abspath(__file__))
#       6 # Build the path to the configuration file
#       7 config_path = os.path.join(script_dir, 'config.txt')
#
# NameError: name '__file__' is not defined

# %%
import os

# Get the directory of the current script
script_dir = os.path.dirname(os.path.abspath('c:\text-summarizer-project-'))

# Build the path to the configuration file
config_path = os.path.join(script_dir, 'config.txt')

# Now, you can open and read the configuration file
with open(config_path, 'r') as file:
    config = file.read()
    print(config)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 10
#       7 config_path = os.path.join(script_dir, 'config.txt')
#       9 # Now, you can open and read the configuration file
# ---> 10 with open(config_path, 'r') as file:
#      11     config = file.read()
#      12     print(config)
#
# File c:\Users\priyansh singh\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...

# %%
import os

script_dir = os.path.dirname(os.path.abspath('c:\text-summarizer-project-'))
config_path = os.path.join(script_dir, 'config.txt')

# Check if the file exists
if os.path.exists(config_path):
    with open(config_path, 'r') as file:
        config = file.read()
        print(config)
else:
    print(f"File not found: {config_path}")
# Out:
# File not found: c:\config.txt

# %%
print(f"Expected config path: {config_path}")
# Out:
# Expected config path: c:\config.txt

# %%
import os
print(os.getcwd())
# Out:
# c:\text-summarizer-project-

# %%
import sys
sys.path.append('c:\\text-summarizer-project-')
from textSummarizer.constants import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 import sys
#       2 sys.path.append('c:\\text-summarizer-project-')
# ----> 3 from textSummarizer.constants import *
#
# ModuleNotFoundError: No module named 'textSummarizer'

# %%
import sys
sys.path.append('c:\text-summarizer-project-')  # Adjust the path as necessary

from textSummarizer.constants import *
from textSummarizer.utils.common import read_yaml, create_dierectories
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       1 import sys
#       2 sys.path.append('c:\text-summarizer-project-')  # Adjust the path as necessary
# ----> 4 from textSummarizer.constants import *
#       5 from textSummarizer.utils.common import read_yaml, create_dierectories
#
# ModuleNotFoundError: No module named 'textSummarizer'

# %%
# %pip install box
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement box (from versions: none)
# ERROR: No matching distribution found for box
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install python-box
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.2 MB 330.3 kB/s eta 0:00:04
#    - -------------------------------------- 0.0/1.2 MB 281.8 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/1.2 MB 238.1 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/1.2 MB 238.1 kB/s eta 0:00:05
#    -- ------------------------------------- 0.1/1.2 MB 306.3 kB/s eta 0:00:04
#    --- ------------------------------------ 0.1/1.2 MB 310.3 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.1/1.2 MB 343.4 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.1/1.2 MB 355.0 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.2 MB 353.1 kB/s eta 0:00:03
# ...

# %%
from pathlib import Path
from box import ConfigBox  # Ensure you have the correct import for ConfigBox

def read_yaml(path_to_yaml: Path) -> ConfigBox:
    # Example content - adjust according to what this function should do
    with open(path_to_yaml, 'r') as file:
        content = file.read()
        # Assume ConfigBox can parse YAML content directly
        config = ConfigBox.from_yaml(content)
        return config

    # If the function is not yet implemented, you can place a pass here
    # pass

# %%
# %pip install typeguard
# Out:
# ...
#   Using cached typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Using cached typeguard-4.3.0-py3-none-any.whl (35 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textSummarizer.constants import *
from textSummarizer.utils.common import read_yaml,  create_directories

# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\priyansh singh\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\priyansh singh\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\priyansh singh\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\priyansh singh\\AppData\\Local\\Programs\\Python\\Python312', '', 'c:\\Users\\priyansh singh\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages', 'c:\\Users\\priyansh singh\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\win32', 'c:\\Users\\priyansh singh\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\priyansh singh\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\Pythonwin']

# %%
import os
print(os.listdir('c:/text-summarizer-project-/textSummarizer/utils'))
# Out:
# ['common.py', '__init__.py', '__pycache__']

# %%
# %pwd
# Out:
# 'c:\\text-summarizer-project-'

# %%
# Define a simple class to hold data ingestion configuration
class data_ingestion_config:
    def __init__(self, root_dir, source_URL, local_data_file, unzip_dir):
        self.root_dir = root_dir
        self.source_URL = source_URL
        self.local_data_file = local_data_file
        self.unzip_dir = unzip_dir

# Define the paths to the configuration files
CONFIG_FILE_PATH = "C:\text-summarizer-project-\config\config.yaml"
PARAMS_FILE_PATH = "C:\text-summarizer-project-\params.yaml"

class ConfigurationManager:
    def __init__(self, config_filepath=CONFIG_FILE_PATH, params_filepath=PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        
        create_directories([self.config['artifacts_root']])

    def get_data_ingestion_config(self) -> data_ingestion_config:
        config = self.config['data_ingestion']
        create_directories([config['root_dir']])
        
        return data_ingestion_config(
            root_dir=config['root_dir'],
            source_URL=config['source_URL'],
            local_data_file=config['local_data_file'],
            unzip_dir=config['unzip_dir']
        )
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\c'
# <>:11: SyntaxWarning: invalid escape sequence '\p'
# <>:10: SyntaxWarning: invalid escape sequence '\c'
# <>:11: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\priyansh singh\AppData\Local\Temp\ipykernel_23420\254246318.py:10: SyntaxWarning: invalid escape sequence '\c'
#   CONFIG_FILE_PATH = "C:\text-summarizer-project-\config\config.yaml"
# C:\Users\priyansh singh\AppData\Local\Temp\ipykernel_23420\254246318.py:11: SyntaxWarning: invalid escape sequence '\p'
#   PARAMS_FILE_PATH = "C:\text-summarizer-project-\params.yaml"

# %%
import os
import urllib.request as request
import zipfile
from textSummarizer.logging import logger
from textSummarizer.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: data_ingestion_config):
        self.config = config


    
    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename, headers = request.urlretrieve(
                url = self.config.source_URL,
                filename = self.config.local_data_file
            )
            logger.info(f"{filename} download! with following info: \n{headers}")
        else:
            logger.info(f"File already exists of size: {get_size(Path(self.config.local_data_file))}")  

        
    
    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
class DataIngestion:
    def __init__(self, config):
        self.config = config

    def download_file(self):
        import requests
        response = requests.get(self.config.source_URL)
        with open(self.config.local_data_file, 'wb') as file:
            file.write(response.content)
        print("Download completed.")

    def extract_zip_file(self):
        from zipfile import ZipFile
        with ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(self.config.unzip_dir)
        print("Extraction completed.")

# %%
# Example of using an absolute path
config_filepath = r'C:\Users\priyansh singh\path\to\config.yaml'  # Modify this path to where your actual file is
params_filepath = r'C:\Users\priyansh singh\path\to\params.yaml'  # Modify this path as needed

# %%
import yaml

def read_yaml(file_path):
    print(f"Attempting to open the file at: {file_path}")  # Debug print
    with open(file_path, 'r') as file:
        return yaml.safe_load(file)

# %%
import logging

def read_yaml(file_path):
    logging.info(f"Attempting to open the file at: {file_path}")  # Info log
    with open(file_path, 'r') as file:
        return yaml.safe_load(file)

# %%
logging.basicConfig(level=logging.INFO)

# %%
import logging
import os

logging.basicConfig(level=logging.INFO)

# Specify the paths directly or ensure they are correctly passed
config_filepath = 'C:\text-summarizer-project-\config\config.yaml'
params_filepath = 'C:\text-summarizer-project-\params.yaml'

print("Config path:", config_filepath)
print("Params path:", params_filepath)

# Check if files exist before attempting to open them
if not os.path.exists(config_filepath) or not os.path.exists(params_filepath):
    logging.error("One or more configuration files are missing.")
    raise SystemExit("Configuration file not found. Please check the paths.")

try:
    config = ConfigurationManager(config_filepath, params_filepath)
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    logging.error(f"An error occurred during data ingestion: {e}")
    raise SystemExit(e)
# Out:
# Config path: C:	ext-summarizer-project-\config\config.yaml
# Params path: C:	ext-summarizer-project-\params.yaml
# [2024-08-24 15:33:25,428: ERROR: 26297616: One or more configuration files are missing.]
# <>:7: SyntaxWarning: invalid escape sequence '\c'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\c'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\priyansh singh\AppData\Local\Temp\ipykernel_23420\26297616.py:7: SyntaxWarning: invalid escape sequence '\c'
#   config_filepath = 'C:\text-summarizer-project-\config\config.yaml'
# C:\Users\priyansh singh\AppData\Local\Temp\ipykernel_23420\26297616.py:8: SyntaxWarning: invalid escape sequence '\p'
#   params_filepath = 'C:\text-summarizer-project-\params.yaml'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Configuration file not found. Please check the paths.
# ...

# %%
print("Config path:", config_filepath)
print("Params path:", params_filepath)
# Out:
# Config path: C:\Users\priyansh singh\path\to\config.yaml
# Params path: C:\Users\priyansh singh\path\to\params.yaml

# %%
print("Checking paths...")
print("Config file path:", config_filepath)
print("Params file path:", params_filepath)
# Out:
# Checking paths...
# Config file path: path/to/config.yaml
# Params file path: path/to/params.yaml

# %%
import os

config_file_path = r'C:\text-summarizer-project-\config\config.yaml'  # Update this to your actual path

# Check if the file exists
if not os.path.exists(config_file_path):
    print(f"Error: No such file or directory: '{config_file_path}'")
else:
    print(f"File found: {config_file_path}")
# Out:
# File found: C:\text-summarizer-project-\config\config.yaml

# %%
import yaml
import os
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def read_yaml(file_path):
    """Reads and returns the content of a YAML file safely.
    
    Args:
        file_path (str): The path to the YAML file.
    
    Returns:
        dict: Parsed YAML data or None if an error occurred.
    """
    try:
        with open(file_path, 'r') as file:
            return yaml.safe_load(file)
    except FileNotFoundError:
        logging.error(f"File not found: {file_path}")
        return None
    except yaml.YAMLError as exc:
        logging.error(f"Error parsing YAML file: {exc}")
        return None
    except Exception as exc:
        logging.error(f"An unexpected error occurred: {exc}")
        return None

def main():
    # Use an environment variable for the configuration path, with a default fallback
    config_file_path = os.getenv('CONFIG_PATH', r'C:\text-summarizer-project-\config\config.yaml')

    # Check if the file exists before trying to open it
    if os.path.exists(config_file_path):
        config = read_yaml(config_file_path)
        if config is not None:
            logging.info("Configuration loaded successfully.")
            # Proceed with using the configuration as needed
            # For example: print(config) or process further based on config
            print(config)
    else:
        logging.error(f"No such file or directory: '{config_file_path}'")

if __name__ == "__main__":
    main()
# Out:
# [2024-08-24 14:54:25,137: ERROR: 739556645: Error parsing YAML file: while parsing a block mapping
#   in "C:\text-summarizer-project-\config\config.yaml", line 1, column 1
# expected <block end>, but found '<block mapping start>'
#   in "C:\text-summarizer-project-\config\config.yaml", line 11, column 3]

# %%
import yaml
from pathlib import Path

def read_yaml(path_to_yaml: Path):
    """Read a YAML file and return its content."""
    try:
        with open(path_to_yaml, 'r') as file:
            return yaml.safe_load(file)
    except Exception as e:
        print(f"Error reading YAML file: {path_to_yaml}. Error: {e}")
        return None

# Use raw strings for Windows paths to avoid issues with backslashes
config_filepath = r'C:\text-summarizer-project-\config\config.yaml'
params_filepath = r'C:\text-summarizer-project-\config\params.yaml'

# Convert string paths to Path objects
config_path = Path(config_filepath)
params_path = Path(params_filepath)

# Create an instance of ConfigurationManager
# Note: ConfigurationManager needs to be defined somewhere in your code.
config = ConfigurationManager(config_path, params_path)
# Out:
# Error reading YAML file: C:\text-summarizer-project-\config\config.yaml. Error: while parsing a block mapping
#   in "C:\text-summarizer-project-\config\config.yaml", line 1, column 1
# expected <block end>, but found '<block mapping start>'
#   in "C:\text-summarizer-project-\config\config.yaml", line 11, column 3
# Error reading YAML file: C:\text-summarizer-project-\config\params.yaml. Error: [Errno 2] No such file or directory: 'C:\\text-summarizer-project-\\config\\params.yaml'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 23
#      19 params_path = Path(params_filepath)
#      21 # Create an instance of ConfigurationManager
#      22 # Note: ConfigurationManager needs to be defined somewhere in your code.
# ---> 23 config = ConfigurationManager(config_path, params_path)
#
# ...

# %%
if not config_path.exists() or not params_path.exists():
    print(f"Configuration or parameters file does not exist. Please check the paths.")
# Out:
# Configuration or parameters file does not exist. Please check the paths.

# %%
from pathlib import Path

# Correct initialization of the Path object
config_filepath = 'C:\\text-summarizer-project-\\config\\config.yaml'  # Use raw string or double backslashes
params_filepath = 'C:\\text-summarizer-project-\\config\\params.yaml'

config_path = Path(config_filepath)
params_path = Path(params_filepath)

# Check if paths are correct (for debugging)
print("Config path:", config_path)
print("Params path:", params_path)

if not config_path.exists():
    print(f"Configuration file does not exist at: {config_path}")
if not params_path.exists():
    print(f"Parameters file does not exist at: {params_path}")
# Out:
# Config path: C:\text-summarizer-project-\config\config.yaml
# Params path: C:\text-summarizer-project-\config\params.yaml
# Parameters file does not exist at: C:\text-summarizer-project-\config\params.yaml

# %%
config_filepath = r'C:\text-summarizer-project-\config\config.yaml'  # Windows path example with raw string
params_filepath = r'C:\text-summarizer-project-\params.yaml'  # Adjust the path according to your file location

# %%
from pathlib import Path

config_path = Path(config_filepath)
params_path = Path(params_filepath)

if not config_path.exists() or not params_path.exists():
    print("Configuration or parameters file does not exist. Please check the paths.")
    # Exit or handle the error appropriately
else:
    config = ConfigurationManager(config_path, params_path)
# Out:
# Configuration or parameters file does not exist. Please check the paths.

# %%
import yaml
from pathlib import Path

def read_yaml(path_to_yaml: Path):
    try:
        with open(path_to_yaml, 'r') as file:
            return yaml.safe_load(file)
    except FileNotFoundError:
        print(f"File not found: {path_to_yaml}")
    except yaml.YAMLError as exc:
        print(f"Error parsing YAML file: {exc}")
    except Exception as e:
        print(f"Unexpected error: {e}")
    return None

# %%
class ConfigurationManager:
    def __init__(self, config_path: Path, params_path: Path):
        self.config = read_yaml(config_path)
        self.params = read_yaml(params_path)

        if self.config is None or 'artifacts_root' not in self.config:
            raise ValueError("Configuration data is invalid or missing required keys.")

        create_directories([self.config['artifacts_root']])

# %%
import os

def create_directories(paths):
    for path in paths:
        os.makedirs(path, exist_ok=True)  # Use exist_ok to prevent errors if the directory exists

# %%
import yaml
from pathlib import Path

def read_yaml(path_to_yaml: Path):
    """Read a YAML file and return its content."""
    try:
        with open(path_to_yaml, 'r') as file:
            return yaml.safe_load(file)
    except Exception as e:
        print(f"Error reading YAML file: {path_to_yaml}. Error: {e}")
        return None

# Use raw strings for Windows paths to avoid issues with backslashes
config_filepath = r'C:\text-summarizer-project-\config\config.yaml'
params_filepath = r'C:\text-summarizer-project-\config\params.yaml'

# Convert string paths to Path objects
config_path = Path(config_filepath)
params_path = Path(params_filepath)

# Create an instance of ConfigurationManager
# Note: ConfigurationManager needs to be defined somewhere in your code.
config = ConfigurationManager(config_path, params_path)
# Out:
# Error reading YAML file: C:\text-summarizer-project-\config\config.yaml. Error: while parsing a block mapping
#   in "C:\text-summarizer-project-\config\config.yaml", line 1, column 1
# expected <block end>, but found '<block mapping start>'
#   in "C:\text-summarizer-project-\config\config.yaml", line 11, column 3
# Error reading YAML file: C:\text-summarizer-project-\config\params.yaml. Error: [Errno 2] No such file or directory: 'C:\\text-summarizer-project-\\config\\params.yaml'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 23
#      19 params_path = Path(params_filepath)
#      21 # Create an instance of ConfigurationManager
#      22 # Note: ConfigurationManager needs to be defined somewhere in your code.
# ---> 23 config = ConfigurationManager(config_path, params_path)
#
# ...

# %%
import yaml
import logging

def read_yaml(path_to_yaml):
    try:
        with open(path_to_yaml, 'r') as file:
            data = yaml.safe_load(file)
            if data is None:
                raise ValueError(f"No data found in YAML file at {path_to_yaml}")
            return data
    except FileNotFoundError:
        raise FileNotFoundError(f"YAML file not found at {path_to_yaml}")
    except yaml.YAMLError as exc:
        raise RuntimeError(f"Error parsing YAML file at {path_to_yaml}: {exc}")

# %%
import logging

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

try:
    config_filepath = r'C:\text-summarizer-project-\config\config.yaml'
    params_filepath = r'C:\text-summarizer-project-\params.yaml'

    config = ConfigurationManager(config_filepath, params_filepath)
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()

except FileNotFoundError as fnfe:
    logging.error(f"File error: {fnfe}")
except KeyError as ke:
    logging.error(f"Configuration error: {ke}")
except Exception as e:
    logging.error(f"An unexpected error occurred: {e}")
# Out:
# [2024-08-24 15:53:56,625: ERROR: 2925353913: An unexpected error occurred: Error parsing YAML file at C:\text-summarizer-project-\config\config.yaml: while parsing a block mapping
#   in "C:\text-summarizer-project-\config\config.yaml", line 1, column 1
# expected <block end>, but found '<block mapping start>'
#   in "C:\text-summarizer-project-\config\config.yaml", line 11, column 3]

# %%
try:
    # Using raw strings to prevent issues with backslashes
    config_filepath = r'C:\text-summarizer-project-\config\config.yaml'
    params_filepath = r'C:\text-summarizer-project-\params.yaml'

    config = ConfigurationManager(config_filepath, params_filepath)
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()

except FileNotFoundError as fnfe:
    print(f"File error: {fnfe}")
except KeyError as ke:
    print(f"Configuration error: {ke}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# An unexpected error occurred: Error parsing YAML file at C:\text-summarizer-project-\config\config.yaml: while parsing a block mapping
#   in "C:\text-summarizer-project-\config\config.yaml", line 1, column 1
# expected <block end>, but found '<block mapping start>'
#   in "C:\text-summarizer-project-\config\config.yaml", line 11, column 3

# %%
class ConfigurationManager:
    def __init__(self, config_filepath, params_filepath):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        if 'artifacts_root' not in self.config:
            raise KeyError("Missing 'artifacts_root' key in configuration data.")
        
        create_directories([self.config['artifacts_root']])

# %%
# Out:
# An unexpected error occurred: [Errno 22] Invalid argument: 'C:\text-summarizer-project-\\config\\config.yaml'
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\priyansh singh\AppData\Local\Temp\ipykernel_23420\381663777.py:2: SyntaxWarning: invalid escape sequence '\c'
#   config_filepath = 'C:\text-summarizer-project-\config\config.yaml'
# C:\Users\priyansh singh\AppData\Local\Temp\ipykernel_23420\381663777.py:3: SyntaxWarning: invalid escape sequence '\p'
#   params_filepath = 'C:\text-summarizer-project-\params.yaml'

# %%
try:
    # Use raw strings for Windows file paths to avoid issues with escape sequences
    config_filepath = r'C:\text-summarizer-project-\config\config.yaml'
    params_filepath = r'C:\text-summarizer-project-\params.yaml'

    config = ConfigurationManager(config_filepath, params_filepath)
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()

except FileNotFoundError as fnfe:
    print(f"File error: {fnfe}")
except KeyError as ke:
    print(f"Configuration error: {ke}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# An unexpected error occurred: Error parsing YAML file at C:\text-summarizer-project-\config\config.yaml: while parsing a block mapping
#   in "C:\text-summarizer-project-\config\config.yaml", line 1, column 1
# expected <block end>, but found '<block mapping start>'
#   in "C:\text-summarizer-project-\config\config.yaml", line 11, column 3

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 8
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[124], line 2
#       1 try:
# ----> 2     config = ConfigurationManager()
#       3     data_ingestion_config = config.get_data_ingestion_config()
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
#
# TypeError: ConfigurationManager.__init__() missing 2 required positional arguments: 'config_filepath' and 'params_filepath'
